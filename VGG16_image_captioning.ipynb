# %%
import numpy as np
import pandas as pd
import os
import tensorflow as tf
from tqdm import tqdm
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import Sequence
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, Activation, Dropout, Flatten, Dense, Input, Layer
from tensorflow.keras.layers import Embedding, LSTM, add, Concatenate, Reshape, concatenate, Bidirectional
from tensorflow.keras.applications import VGG16, ResNet50, DenseNet201
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
from textwrap import wrap

plt.rcParams['font.size'] = 12
sns.set_style("dark")
warnings.filterwarnings('ignore')

# %%
image_path = '/kaggle/input/flickr8k/images'

# %%
data = pd.read_csv("/kaggle/input/flickr2k-captions/output.txt")
data.head()
# Out:
#                        image  \
# 0  1000268201_693b08cb0e.jpg
# 1  1000268201_693b08cb0e.jpg
# 2  1000268201_693b08cb0e.jpg
# 3  1000268201_693b08cb0e.jpg
# 4  1000268201_693b08cb0e.jpg
#
#                                              caption
# 0  A child in a pink dress is climbing up a set o...
# 1              A girl going into a wooden building .
# 2   A little girl climbing into a wooden playhouse .
# 3  A little girl climbing the stairs to her playh...
# 4  A little girl in a pink dress going into a woo...

# %%
def readImage(path,img_size=224):
    img = load_img(path,color_mode='rgb',target_size=(img_size,img_size))
    img = img_to_array(img)
    img = img/255.
    
    return img

def display_images(temp_df):
    temp_df = temp_df.reset_index(drop=True)
    plt.figure(figsize = (20 , 20))
    n = 0
    for i in range(15):
        n+=1
        plt.subplot(5 , 5, n)
        plt.subplots_adjust(hspace = 0.7, wspace = 0.3)
        image = readImage(f"/kaggle/input/flickr8k/images/{temp_df.image[i]}")
        plt.imshow(image)
        plt.title("\n".join(wrap(temp_df.caption[i], 20)))
        plt.axis("off")

# %% [markdown]
# # **Visualization**
# - Images and their corresponding captions

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
img = mpimg.imread('/kaggle/input/flicker8k-2k/Flickr8k_2k/Flicker8k_2kDataset/3094568845_d0b56c5651.jpg')
 
# Output Images
plt.imshow(img)

# %%
display_images(data.sample(15))

# %% [markdown]
# # **Caption Text Preprocessing Steps**
# - Convert sentences into lowercase
# - Remove special characters and numbers present in the text
# - Remove extra spaces
# - Remove single characters
# - Add a starting and an ending tag to the sentences to indicate the beginning and the ending of a sentence
#
# <img src='http://zjpnrm2br14wspo448nls17u-wpengine.netdna-ssl.com/wp-content/uploads/2020/09/processing-steps.png' >

# %%
def text_preprocessing(data):
    data['caption'] = data['caption'].apply(lambda x: x.lower())
    data['caption'] = data['caption'].apply(lambda x: x.replace("[^A-Za-z]",""))
    data['caption'] = data['caption'].apply(lambda x: x.replace("\s+"," "))
    data['caption'] = data['caption'].apply(lambda x: " ".join([word for word in x.split() if len(word)>1]))
    data['caption'] = "startseq "+data['caption']+" endseq"
    return data

# %% [markdown]
# ## __Preprocessed Text__

# %%
data = text_preprocessing(data)
captions = data['caption'].tolist()
captions[:10]
# Out:
# ['startseq child in pink dress is climbing up set of stairs in an entry way endseq',
#  'startseq girl going into wooden building endseq',
#  'startseq little girl climbing into wooden playhouse endseq',
#  'startseq little girl climbing the stairs to her playhouse endseq',
#  'startseq little girl in pink dress going into wooden cabin endseq',
#  'startseq black dog and spotted dog are fighting endseq',
#  'startseq black dog and tri-colored dog playing with each other on the road endseq',
#  'startseq black dog and white dog with brown spots are staring at each other in the street endseq',
#  'startseq two dogs of different breeds looking at each other on the road endseq',
#  'startseq two dogs on pavement moving toward each other endseq']

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(captions)
vocab_size = len(tokenizer.word_index) + 1
max_length = max(len(caption.split()) for caption in captions)

images = data['image'].unique().tolist()
nimages = len(images)

split_index = round(0.85*nimages)
train_images = images[:split_index]
val_images = images[split_index:]

train = data[data['image'].isin(train_images)]
test = data[data['image'].isin(val_images)]

train.reset_index(inplace=True,drop=True)
test.reset_index(inplace=True,drop=True)

tokenizer.texts_to_sequences([captions[1]])[0]
# Out:
# [1, 15, 356, 53, 183, 155, 2]

# %%
model = VGG16()
fe = Model(inputs=model.input, outputs=model.layers[-2].output)

img_size = 224
features = {}
for image in tqdm(data['image'].unique().tolist()):
    img = load_img(os.path.join(image_path,image),target_size=(img_size,img_size))
    img = img_to_array(img)
    img = img/255.
    img = np.expand_dims(img,axis=0)
    feature = fe.predict(img, verbose=0)
    features[image] = feature
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467904/553467096 [==============================] - 3s 0us/step
# 553476096/553467096 [==============================] - 3s 0us/step
# 100%|██████████| 1600/1600 [01:49<00:00, 14.63it/s]

# %%
class CustomDataGenerator(Sequence):
    
    def __init__(self, df, X_col, y_col, batch_size, directory, tokenizer, 
                 vocab_size, max_length, features,shuffle=True):
    
        self.df = df.copy()
        self.X_col = X_col
        self.y_col = y_col
        self.directory = directory
        self.batch_size = batch_size
        self.tokenizer = tokenizer
        self.vocab_size = vocab_size
        self.max_length = max_length
        self.features = features
        self.shuffle = shuffle
        self.n = len(self.df)
        
    def on_epoch_end(self):
        if self.shuffle:
            self.df = self.df.sample(frac=1).reset_index(drop=True)
    
    def __len__(self):
        return self.n // self.batch_size
    
    def __getitem__(self,index):
    
        batch = self.df.iloc[index * self.batch_size:(index + 1) * self.batch_size,:]
        X1, X2, y = self.__get_data(batch)        
        return (X1, X2), y
    
    def __get_data(self,batch):
        
        X1, X2, y = list(), list(), list()
        
        images = batch[self.X_col].tolist()
           
        for image in images:
            feature = self.features[image][0]
            
            captions = batch.loc[batch[self.X_col]==image, self.y_col].tolist()
            for caption in captions:
                seq = self.tokenizer.texts_to_sequences([caption])[0]

                for i in range(1,len(seq)):
                    in_seq, out_seq = seq[:i], seq[i]
                    in_seq = pad_sequences([in_seq], maxlen=self.max_length)[0]
                    out_seq = to_categorical([out_seq], num_classes=self.vocab_size)[0]
                    X1.append(feature)
                    X2.append(in_seq)
                    y.append(out_seq)
            
        X1, X2, y = np.array(X1), np.array(X2), np.array(y)
                
        return X1, X2, y

# %% [markdown]
# # **Modelling**
# - The image embedding representations are concatenated with the first word of sentence ie. starseq and passed to the LSTM network
# - The LSTM network starts generating words after each input thus forming a sentence at the end

# %% [markdown]
# <img src='https://raw.githubusercontent.com/yunjey/pytorch-tutorial/master/tutorials/03-advanced/image_captioning/png/model.png'>

# %%
input1 = Input(shape=(4096,))
input2 = Input(shape=(max_length,))

img_features = Dense(256, activation='relu')(input1)
img_features_reshaped = Reshape((1, 256), input_shape=(256,))(img_features)

sentence_features = Embedding(vocab_size, 256, mask_zero=False)(input2)
merged = concatenate([img_features_reshaped,sentence_features],axis=1)
sentence_features = LSTM(256)(merged)
x = Dropout(0.5)(sentence_features)
x = add([x, img_features])
x = Dense(128, activation='relu')(x)
x = Dropout(0.5)(x)
output = Dense(vocab_size, activation='softmax')(x)

caption_model = Model(inputs=[input1,input2], outputs=output)
caption_model.compile(loss='categorical_crossentropy',optimizer='adam')

# %%
from tensorflow.keras.utils import plot_model

# %%
plot_model(caption_model)

# %%
caption_model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 4096)]       0
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 256)          1048832     input_4[0][0]
# __________________________________________________________________________________________________
# input_5 (InputLayer)            [(None, 31)]         0
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 256)       0           dense_3[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 31, 256)      1026816     input_5[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 256)      0           reshape_1[0][0]
#                                                                  embedding_1[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 256)          525312      concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 256)          0           lstm_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 256)          0           dropout_2[0][0]
#                                                                  dense_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 128)          32896       add_1[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 128)          0           dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 4011)         517419      dropout_3[0][0]
# ==================================================================================================
# Total params: 3,151,275
# Trainable params: 3,151,275
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
train_generator = CustomDataGenerator(df=train,X_col='image',y_col='caption',batch_size=64,directory=image_path,
                                      tokenizer=tokenizer,vocab_size=vocab_size,max_length=max_length,features=features)

validation_generator = CustomDataGenerator(df=test,X_col='image',y_col='caption',batch_size=64,directory=image_path,
                                      tokenizer=tokenizer,vocab_size=vocab_size,max_length=max_length,features=features)

# %%
model_name = "model.h5"
checkpoint = ModelCheckpoint(model_name,
                            monitor="val_loss",
                            mode="min",
                            save_best_only = True,
                            verbose=1)

earlystopping = EarlyStopping(monitor='val_loss',min_delta = 0, patience = 5, verbose = 1, restore_best_weights=True)

learning_rate_reduction = ReduceLROnPlateau(monitor='val_loss', 
                                            patience=3, 
                                            verbose=1, 
                                            factor=0.2, 
                                            min_lr=0.00000001)

# %%
history = caption_model.fit(
        train_generator,
        epochs=100,
        validation_data=validation_generator,
        callbacks=[checkpoint,learning_rate_reduction])
# Out:
# Epoch 1/100
# 106/106 [==============================] - 46s 411ms/step - loss: 5.9677 - val_loss: 5.3112
#
# Epoch 00001: val_loss improved from inf to 5.31123, saving model to model.h5
# Epoch 2/100
# 106/106 [==============================] - 10s 90ms/step - loss: 5.2224 - val_loss: 4.8191
#
# Epoch 00002: val_loss improved from 5.31123 to 4.81910, saving model to model.h5
# Epoch 3/100
# 106/106 [==============================] - 10s 91ms/step - loss: 4.8141 - val_loss: 4.5372
#
# Epoch 00003: val_loss improved from 4.81910 to 4.53717, saving model to model.h5
# Epoch 4/100
# 106/106 [==============================] - 10s 91ms/step - loss: 4.5366 - val_loss: 4.3718
#
# Epoch 00004: val_loss improved from 4.53717 to 4.37178, saving model to model.h5
# Epoch 5/100
# 106/106 [==============================] - 10s 92ms/step - loss: 4.3628 - val_loss: 4.2477
#
# Epoch 00005: val_loss improved from 4.37178 to 4.24768, saving model to model.h5
# Epoch 6/100
# 106/106 [==============================] - 9s 88ms/step - loss: 4.2280 - val_loss: 4.1696
#
# Epoch 00006: val_loss improved from 4.24768 to 4.16960, saving model to model.h5
# Epoch 7/100
# 106/106 [==============================] - 10s 92ms/step - loss: 4.1158 - val_loss: 4.1661
#
# Epoch 00007: val_loss improved from 4.16960 to 4.16613, saving model to model.h5
# Epoch 8/100
# 106/106 [==============================] - 9s 89ms/step - loss: 4.0107 - val_loss: 4.1234
#
# Epoch 00008: val_loss improved from 4.16613 to 4.12342, saving model to model.h5
# Epoch 9/100
# 106/106 [==============================] - 9s 89ms/step - loss: 3.9271 - val_loss: 4.1180
#
# Epoch 00009: val_loss improved from 4.12342 to 4.11798, saving model to model.h5
# Epoch 10/100
# 106/106 [==============================] - 10s 94ms/step - loss: 3.8373 - val_loss: 4.1136
#
# Epoch 00010: val_loss improved from 4.11798 to 4.11365, saving model to model.h5
# Epoch 11/100
# 106/106 [==============================] - 10s 90ms/step - loss: 3.7621 - val_loss: 4.1086
#
# Epoch 00011: val_loss improved from 4.11365 to 4.10856, saving model to model.h5
# Epoch 12/100
# 106/106 [==============================] - 10s 90ms/step - loss: 3.7031 - val_loss: 4.1022
#
# Epoch 00012: val_loss improved from 4.10856 to 4.10216, saving model to model.h5
# Epoch 13/100
# 106/106 [==============================] - 10s 94ms/step - loss: 3.6424 - val_loss: 4.1356
#
# Epoch 00013: val_loss did not improve from 4.10216
# Epoch 14/100
# 106/106 [==============================] - 9s 88ms/step - loss: 3.5809 - val_loss: 4.0933
#
# Epoch 00014: val_loss improved from 4.10216 to 4.09332, saving model to model.h5
# Epoch 15/100
# 106/106 [==============================] - 9s 87ms/step - loss: 3.5222 - val_loss: 4.1496
#
# Epoch 00015: val_loss did not improve from 4.09332
# Epoch 16/100
# 106/106 [==============================] - 10s 93ms/step - loss: 3.4804 - val_loss: 4.1331
#
# Epoch 00016: val_loss did not improve from 4.09332
# Epoch 17/100
# 106/106 [==============================] - 9s 88ms/step - loss: 3.4303 - val_loss: 4.1442
#
# Epoch 00017: val_loss did not improve from 4.09332
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 18/100
# 106/106 [==============================] - 10s 90ms/step - loss: 3.3164 - val_loss: 4.2193
#
# Epoch 00018: val_loss did not improve from 4.09332
# Epoch 19/100
# 106/106 [==============================] - 9s 88ms/step - loss: 3.2907 - val_loss: 4.1918
#
# Epoch 00019: val_loss did not improve from 4.09332
# Epoch 20/100
# 106/106 [==============================] - 10s 93ms/step - loss: 3.2702 - val_loss: 4.1918
#
# Epoch 00020: val_loss did not improve from 4.09332
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 21/100
# 106/106 [==============================] - 9s 89ms/step - loss: 3.2486 - val_loss: 4.1912
#
# Epoch 00021: val_loss did not improve from 4.09332
# Epoch 22/100
# 106/106 [==============================] - 9s 89ms/step - loss: 3.2487 - val_loss: 4.2206
#
# Epoch 00022: val_loss did not improve from 4.09332
# Epoch 23/100
# 106/106 [==============================] - 10s 94ms/step - loss: 3.2398 - val_loss: 4.2148
#
# Epoch 00023: val_loss did not improve from 4.09332
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# Epoch 24/100
# 106/106 [==============================] - 9s 88ms/step - loss: 3.2333 - val_loss: 4.1907
#
# Epoch 00024: val_loss did not improve from 4.09332
# Epoch 25/100
# 106/106 [==============================] - 10s 90ms/step - loss: 3.2336 - val_loss: 4.2068
#
# Epoch 00025: val_loss did not improve from 4.09332
# Epoch 26/100
# 106/106 [==============================] - 10s 93ms/step - loss: 3.2259 - val_loss: 4.2443
#
# Epoch 00026: val_loss did not improve from 4.09332
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# Epoch 27/100
# 106/106 [==============================] - 10s 90ms/step - loss: 3.2301 - val_loss: 4.2151
#
# Epoch 00027: val_loss did not improve from 4.09332
# Epoch 28/100
# 106/106 [==============================] - 9s 89ms/step - loss: 3.2311 - val_loss: 4.1932
#
# Epoch 00028: val_loss did not improve from 4.09332
# Epoch 29/100
# 106/106 [==============================] - 10s 94ms/step - loss: 3.2325 - val_loss: 4.1863
#
# Epoch 00029: val_loss did not improve from 4.09332
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# Epoch 30/100
# 106/106 [==============================] - 10s 90ms/step - loss: 3.2312 - val_loss: 4.2318
#
# Epoch 00030: val_loss did not improve from 4.09332
# Epoch 31/100
# 106/106 [==============================] - 9s 89ms/step - loss: 3.2339 - val_loss: 4.2144
#
# Epoch 00031: val_loss did not improve from 4.09332
# Epoch 32/100
# 106/106 [==============================] - 9s 88ms/step - loss: 3.2277 - val_loss: 4.1907
#
# Epoch 00032: val_loss did not improve from 4.09332
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-08.
# Epoch 33/100
# 106/106 [==============================] - 10s 92ms/step - loss: 3.2276 - val_loss: 4.1995
#
# Epoch 00033: val_loss did not improve from 4.09332
# Epoch 34/100
# 106/106 [==============================] - 10s 91ms/step - loss: 3.2307 - val_loss: 4.1935
#
# Epoch 00034: val_loss did not improve from 4.09332
# Epoch 35/100
# 106/106 [==============================] - 9s 89ms/step - loss: 3.2268 - val_loss: 4.1793
#
# Epoch 00035: val_loss did not improve from 4.09332
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 1.2800001059076749e-08.
# Epoch 36/100
# 106/106 [==============================] - 10s 93ms/step - loss: 3.2302 - val_loss: 4.1487
#
# Epoch 00036: val_loss did not improve from 4.09332
# Epoch 37/100
# 106/106 [==============================] - 10s 90ms/step - loss: 3.2254 - val_loss: 4.2272
#
# Epoch 00037: val_loss did not improve from 4.09332
# Epoch 38/100
# 106/106 [==============================] - 9s 89ms/step - loss: 3.2256 - val_loss: 4.2479
#
# Epoch 00038: val_loss did not improve from 4.09332
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 1e-08.
# Epoch 39/100
# 106/106 [==============================] - 11s 100ms/step - loss: 3.2279 - val_loss: 4.2184
#
# Epoch 00039: val_loss did not improve from 4.09332
# Epoch 40/100
# 106/106 [==============================] - 9s 89ms/step - loss: 3.2335 - val_loss: 4.2117
#
# Epoch 00040: val_loss did not improve from 4.09332
# Epoch 41/100
# 106/106 [==============================] - 9s 89ms/step - loss: 3.2304 - val_loss: 4.2203
#
# Epoch 00041: val_loss did not improve from 4.09332
# Epoch 42/100
# 106/106 [==============================] - 10s 92ms/step - loss: 3.2306 - val_loss: 4.2263
#
# Epoch 00042: val_loss did not improve from 4.09332
# Epoch 43/100
# 106/106 [==============================] - 9s 90ms/step - loss: 3.2309 - val_loss: 4.2469
#
# Epoch 00043: val_loss did not improve from 4.09332
# Epoch 44/100
# 106/106 [==============================] - 9s 89ms/step - loss: 3.2326 - val_loss: 4.1966
#
# Epoch 00044: val_loss did not improve from 4.09332
# Epoch 45/100
# 106/106 [==============================] - 10s 90ms/step - loss: 3.2290 - val_loss: 4.2267
#
# Epoch 00045: val_loss did not improve from 4.09332
# Epoch 46/100
# 106/106 [==============================] - 10s 96ms/step - loss: 3.2308 - val_loss: 4.2188
#
# Epoch 00046: val_loss did not improve from 4.09332
# Epoch 47/100
# 106/106 [==============================] - 9s 89ms/step - loss: 3.2325 - val_loss: 4.2328
#
# Epoch 00047: val_loss did not improve from 4.09332
# Epoch 48/100
# 106/106 [==============================] - 9s 88ms/step - loss: 3.2281 - val_loss: 4.1890
#
# Epoch 00048: val_loss did not improve from 4.09332
# Epoch 49/100
# 106/106 [==============================] - 10s 92ms/step - loss: 3.2315 - val_loss: 4.2056
#
# Epoch 00049: val_loss did not improve from 4.09332
# Epoch 50/100
# 106/106 [==============================] - 9s 88ms/step - loss: 3.2313 - val_loss: 4.1709
#
# Epoch 00050: val_loss did not improve from 4.09332
# Epoch 51/100
# 106/106 [==============================] - 9s 88ms/step - loss: 3.2282 - val_loss: 4.1667
#
# Epoch 00051: val_loss did not improve from 4.09332
# Epoch 52/100
# 106/106 [==============================] - 10s 92ms/step - loss: 3.2192 - val_loss: 4.1984
#
# Epoch 00052: val_loss did not improve from 4.09332
# Epoch 53/100
# 106/106 [==============================] - 9s 89ms/step - loss: 3.2291 - val_loss: 4.2204
#
# Epoch 00053: val_loss did not improve from 4.09332
# Epoch 54/100
# 106/106 [==============================] - 10s 90ms/step - loss: 3.2278 - val_loss: 4.2421
#
# Epoch 00054: val_loss did not improve from 4.09332
# Epoch 55/100
# 106/106 [==============================] - 10s 92ms/step - loss: 3.2257 - val_loss: 4.1972
#
# Epoch 00055: val_loss did not improve from 4.09332
# Epoch 56/100
# 106/106 [==============================] - 10s 90ms/step - loss: 3.2332 - val_loss: 4.2064
#
# Epoch 00056: val_loss did not improve from 4.09332
# Epoch 57/100
# 106/106 [==============================] - 9s 86ms/step - loss: 3.2269 - val_loss: 4.2225
#
# Epoch 00057: val_loss did not improve from 4.09332
# Epoch 58/100
# 106/106 [==============================] - 10s 91ms/step - loss: 3.2275 - val_loss: 4.1796
#
# Epoch 00058: val_loss did not improve from 4.09332
# Epoch 59/100
# 106/106 [==============================] - 10s 96ms/step - loss: 3.2261 - val_loss: 4.2202
#
# Epoch 00059: val_loss did not improve from 4.09332
# Epoch 60/100
# 106/106 [==============================] - 9s 87ms/step - loss: 3.2300 - val_loss: 4.2117
#
# Epoch 00060: val_loss did not improve from 4.09332
# Epoch 61/100
# 106/106 [==============================] - 9s 88ms/step - loss: 3.2266 - val_loss: 4.2041
#
# Epoch 00061: val_loss did not improve from 4.09332
# Epoch 62/100
# 106/106 [==============================] - 10s 93ms/step - loss: 3.2275 - val_loss: 4.1722
#
# Epoch 00062: val_loss did not improve from 4.09332
# Epoch 63/100
# 106/106 [==============================] - 9s 88ms/step - loss: 3.2284 - val_loss: 4.1787
#
# Epoch 00063: val_loss did not improve from 4.09332
# Epoch 64/100
# 106/106 [==============================] - 10s 94ms/step - loss: 3.2287 - val_loss: 4.2141
#
# Epoch 00064: val_loss did not improve from 4.09332
# Epoch 65/100
# 106/106 [==============================] - 10s 97ms/step - loss: 3.2276 - val_loss: 4.2022
#
# Epoch 00065: val_loss did not improve from 4.09332
# Epoch 66/100
# 106/106 [==============================] - 10s 92ms/step - loss: 3.2267 - val_loss: 4.2133
#
# Epoch 00066: val_loss did not improve from 4.09332
# Epoch 67/100
# 106/106 [==============================] - 10s 93ms/step - loss: 3.2252 - val_loss: 4.1805
#
# Epoch 00067: val_loss did not improve from 4.09332
# Epoch 68/100
# 106/106 [==============================] - 10s 92ms/step - loss: 3.2308 - val_loss: 4.2165
#
# Epoch 00068: val_loss did not improve from 4.09332
# Epoch 69/100
# 106/106 [==============================] - 9s 89ms/step - loss: 3.2245 - val_loss: 4.2066
#
# Epoch 00069: val_loss did not improve from 4.09332
# Epoch 70/100
# 106/106 [==============================] - 9s 88ms/step - loss: 3.2234 - val_loss: 4.2099
#
# Epoch 00070: val_loss did not improve from 4.09332
# Epoch 71/100
# 106/106 [==============================] - 9s 88ms/step - loss: 3.2353 - val_loss: 4.1517
#
# Epoch 00071: val_loss did not improve from 4.09332
# Epoch 72/100
# 106/106 [==============================] - 10s 94ms/step - loss: 3.2295 - val_loss: 4.2233
#
# Epoch 00072: val_loss did not improve from 4.09332
# Epoch 73/100
# 106/106 [==============================] - 10s 89ms/step - loss: 3.2270 - val_loss: 4.2293
#
# Epoch 00073: val_loss did not improve from 4.09332
# Epoch 74/100
# 106/106 [==============================] - 10s 91ms/step - loss: 3.2352 - val_loss: 4.2034
#
# Epoch 00074: val_loss did not improve from 4.09332
# Epoch 75/100
# 106/106 [==============================] - 10s 92ms/step - loss: 3.2315 - val_loss: 4.2009
#
# Epoch 00075: val_loss did not improve from 4.09332
# Epoch 76/100
# 106/106 [==============================] - 10s 92ms/step - loss: 3.2310 - val_loss: 4.2312
#
# Epoch 00076: val_loss did not improve from 4.09332
# Epoch 77/100
# 106/106 [==============================] - 10s 94ms/step - loss: 3.2289 - val_loss: 4.2111
#
# Epoch 00077: val_loss did not improve from 4.09332
# Epoch 78/100
# 106/106 [==============================] - 10s 96ms/step - loss: 3.2345 - val_loss: 4.2218
#
# Epoch 00078: val_loss did not improve from 4.09332
# Epoch 79/100
# 106/106 [==============================] - 9s 89ms/step - loss: 3.2293 - val_loss: 4.2104
#
# Epoch 00079: val_loss did not improve from 4.09332
# Epoch 80/100
# 106/106 [==============================] - 10s 91ms/step - loss: 3.2295 - val_loss: 4.1845
#
# Epoch 00080: val_loss did not improve from 4.09332
# Epoch 81/100
# 106/106 [==============================] - 10s 94ms/step - loss: 3.2307 - val_loss: 4.2076
#
# Epoch 00081: val_loss did not improve from 4.09332
# Epoch 82/100
# 106/106 [==============================] - 9s 89ms/step - loss: 3.2271 - val_loss: 4.2469
#
# Epoch 00082: val_loss did not improve from 4.09332
# Epoch 83/100
# 106/106 [==============================] - 9s 88ms/step - loss: 3.2279 - val_loss: 4.2168
#
# Epoch 00083: val_loss did not improve from 4.09332
# Epoch 84/100
# 106/106 [==============================] - 9s 89ms/step - loss: 3.2282 - val_loss: 4.2146
#
# Epoch 00084: val_loss did not improve from 4.09332
# Epoch 85/100
# 106/106 [==============================] - 10s 91ms/step - loss: 3.2291 - val_loss: 4.2166
#
# Epoch 00085: val_loss did not improve from 4.09332
# Epoch 86/100
# 106/106 [==============================] - 9s 89ms/step - loss: 3.2349 - val_loss: 4.2301
#
# Epoch 00086: val_loss did not improve from 4.09332
# Epoch 87/100
# 106/106 [==============================] - 10s 89ms/step - loss: 3.2270 - val_loss: 4.1970
#
# Epoch 00087: val_loss did not improve from 4.09332
# Epoch 88/100
# 106/106 [==============================] - 10s 94ms/step - loss: 3.2314 - val_loss: 4.1897
#
# Epoch 00088: val_loss did not improve from 4.09332
# Epoch 89/100
# 106/106 [==============================] - 10s 89ms/step - loss: 3.2311 - val_loss: 4.2068
#
# Epoch 00089: val_loss did not improve from 4.09332
# Epoch 90/100
# 106/106 [==============================] - 9s 89ms/step - loss: 3.2298 - val_loss: 4.1902
#
# Epoch 00090: val_loss did not improve from 4.09332
# Epoch 91/100
# 106/106 [==============================] - 10s 93ms/step - loss: 3.2337 - val_loss: 4.2189
#
# Epoch 00091: val_loss did not improve from 4.09332
# Epoch 92/100
# 106/106 [==============================] - 9s 89ms/step - loss: 3.2214 - val_loss: 4.2107
#
# Epoch 00092: val_loss did not improve from 4.09332
# Epoch 93/100
# 106/106 [==============================] - 10s 91ms/step - loss: 3.2298 - val_loss: 4.2077
#
# Epoch 00093: val_loss did not improve from 4.09332
# Epoch 94/100
# 106/106 [==============================] - 10s 94ms/step - loss: 3.2264 - val_loss: 4.2171
#
# Epoch 00094: val_loss did not improve from 4.09332
# Epoch 95/100
# 106/106 [==============================] - 9s 89ms/step - loss: 3.2257 - val_loss: 4.2196
#
# Epoch 00095: val_loss did not improve from 4.09332
# Epoch 96/100
# 106/106 [==============================] - 9s 89ms/step - loss: 3.2311 - val_loss: 4.2317
#
# Epoch 00096: val_loss did not improve from 4.09332
# Epoch 97/100
# 106/106 [==============================] - 9s 89ms/step - loss: 3.2321 - val_loss: 4.2410
#
# Epoch 00097: val_loss did not improve from 4.09332
# Epoch 98/100
# 106/106 [==============================] - 10s 94ms/step - loss: 3.2322 - val_loss: 4.1899
#
# Epoch 00098: val_loss did not improve from 4.09332
# Epoch 99/100
# 106/106 [==============================] - 9s 88ms/step - loss: 3.2325 - val_loss: 4.2022
#
# Epoch 00099: val_loss did not improve from 4.09332
# Epoch 100/100
# 106/106 [==============================] - 9s 89ms/step - loss: 3.2267 - val_loss: 4.2173
#
# Epoch 00100: val_loss did not improve from 4.09332

# %% [markdown]
# # **Inference**
# - Learning Curve (Loss Curve)
# - Assessment of Generated Captions (by checking the relevance of the caption with respect to the image, BLEU Score )

# %%
plt.figure(figsize=(20,8))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# ## **Caption Generation Utility Functions**
# - Utility functions to generate the captions of input images at the inference time.
# - Here the image embeddings are passed along with the first word, followed by which the text embedding of each new word is passed to generate the next word

# %%
def idx_to_word(integer,tokenizer):
    
    for word, index in tokenizer.word_index.items():
        if index==integer:
            return word
    return None

# %%
def predict_caption(model, image, tokenizer, max_length, features):
    
    feature = features[image]
    in_text = "startseq"
    for i in range(max_length):
        sequence = tokenizer.texts_to_sequences([in_text])[0]
        sequence = pad_sequences([sequence], max_length)

        y_pred = model.predict([feature,sequence])
        y_pred = np.argmax(y_pred)
        
        word = idx_to_word(y_pred, tokenizer)
        
        if word is None:
            break
            
        in_text+= " " + word
        
        if word == 'endseq':
            break
            
    return in_text

# %% [markdown]
# ## **Taking 15 Random Samples for Caption Prediction**

# %%
import nltk
from nltk.translate.bleu_score import sentence_bleu

# %%
print(len(test))
# Out:
# 1200

# %%
print(test['image'])
# Out:
# 0       2264316030_600e55748d.jpg
# 1       2264316030_600e55748d.jpg
# 2       2264316030_600e55748d.jpg
# 3       2264316030_600e55748d.jpg
# 4       2264316030_600e55748d.jpg
#                   ...
# 1195    2350400382_ced2b6c91e.jpg
# 1196    2350400382_ced2b6c91e.jpg
# 1197    2350400382_ced2b6c91e.jpg
# 1198    2350400382_ced2b6c91e.jpg
# 1199    2350400382_ced2b6c91e.jpg
# Name: image, Length: 1200, dtype: object

# %%
samples = test.sample(15)
samples.reset_index(drop=True,inplace=True)

# %%
print(samples)
# Out:
#                         image  \
# 0   2271264741_aa8f73f87c.jpg
# 1   2285570521_05015cbf4b.jpg
# 2   2318502106_33f2e4b4fc.jpg
# 3   2335619125_2e2034f2c3.jpg
# 4   2271264741_aa8f73f87c.jpg
# 5   2337757064_08c4033824.jpg
# 6   2274602044_b3d55df235.jpg
# 7   2286235203_af3cd8f243.jpg
# 8   2281075738_230892b241.jpg
# 9   2346772831_b2748ba1f0.jpg
# 10  2286270205_16038dec5a.jpg
# 11  2300229745_af7a20c959.jpg
# 12  2279945145_8815c59217.jpg
# 13  2342478660_faef1afea8.jpg
# 14   233361142_d9d5f0cae9.jpg
#
#                                               caption
# 0   startseq two large dogs walking together throu...
# 1   startseq man is hiking on snow-covered trail e...
# 2   startseq shirtness man juggles batons on the b...
# 3   startseq black dog is running through the snow...
# 4   startseq two dogs run along path strewn with d...
# 5   startseq man holding stick in field of green g...
# 6   startseq old man sitting on the park bench wit...
# 7   startseq young woman is wearing bridal veil ou...
# 8              startseq two black dogs running endseq
# 9   startseq woman in yellow shirt bending over bo...
# 10  startseq golden dog walks carefully around fro...
# 11  startseq white dog is running with an orange f...
# 12  startseq tri-colored dog wearing green collar ...
# 13  startseq little boy wears mr. potao head glass...
# 14  startseq dog in plants crouches to look at cam...

# %%
for index,record in samples.iterrows():

    img = load_img(os.path.join(image_path,record['image']),target_size=(224,224))
    img = img_to_array(img)
    img = img/255.
    
    caption = predict_caption(caption_model, record['image'], tokenizer, max_length, features)
    samples.loc[index,'caption'] = caption

# %% [markdown]
# # **Results**
# - As we can clearly see there is some redundant caption generation e.g. Dog running through the water, overusage of blue shirt for any other coloured cloth
# - The model performance can be further improved by training on more data and using attention mechanism so that our model can focus on relevant areas during the text generation
# - We can also leverage the interprettability of the attention mechanism to understand which areas of the image leads to the generation of which word

# %%
display_images(samples)

# %% [markdown]
# <p style='font-size: 18px'><strong>Conclusion: </strong>This may not be the best performing model, but the objective of this kernel is to give a gist of how Image Captioning problems can be approached. In the future work of this kernel <strong>Attention model</strong> training and <strong>BLEU Score</strong> assessment will be performed.</p>

# %%
import nltk
from nltk.translate.bleu_score import sentence_bleu

# %%
# Reference captions
ref_captions = ['A person is walking on a beach', 'A couple is watching the sunset', 'A dog is playing with a frisbee']

# Generated caption
gen_caption = 'A person is walking on a beach'

# Calculate BLEU score
bleu_score = 0
for ref_caption in ref_captions:
    reference = ref_caption[0].split() # convert reference caption to list of words
    candidate = gen_caption.split() # convert generated caption to list of words
    bleu_score += sentence_bleu([reference], candidate)

bleu_score /= len(ref_captions) # average the BLEU score over all reference captions

print('BLEU score:', bleu_score)
# Out:
# BLEU score: 0.6147881529512643

# %%
print(test)
# Out:
#                           image  \
# 0     2264316030_600e55748d.jpg
# 1     2264316030_600e55748d.jpg
# 2     2264316030_600e55748d.jpg
# 3     2264316030_600e55748d.jpg
# 4     2264316030_600e55748d.jpg
# ...                         ...
# 1195  2350400382_ced2b6c91e.jpg
# 1196  2350400382_ced2b6c91e.jpg
# 1197  2350400382_ced2b6c91e.jpg
# 1198  2350400382_ced2b6c91e.jpg
# 1199  2350400382_ced2b6c91e.jpg
#
#                                                 caption
# 0     startseq brown and black dog walks in the snow...
# 1     startseq brown and black dog walks in the whit...
# 2     startseq brown dog is running through snowy wo...
# 3     startseq dog runs around in the snowy woods en...
# 4     startseq dog with its tongue out walking in th...
# ...                                                 ...
# 1195  startseq black dog caught in mid-jump catching...
# 1196  startseq black dog flies through the air while...
# 1197  startseq black dog jumps in the air to catch t...
# 1198  startseq black dog running with black and whit...
# 1199  startseq dog is in field on very windy day wit...
#
# [1200 rows x 2 columns]

# %%
bleu=[]
for index,record in test.iterrows():
    ref_captions=[]
    if(index%5==0):
        img = load_img(os.path.join(image_path,record['image']),target_size=(224,224))
        img = img_to_array(img)
        img = img/255.
        
    
    caption = predict_caption(caption_model, record['image'], tokenizer, max_length, features)
    bleu_score = 0
    for ref_caption in ref_captions:
        print(ref_caption)
#         reference = ref_caption.split() # convert reference caption to list of words
#         candidate = gen_caption.split() # convert generated caption to list of words
        bleu_score += sentence_bleu([reference], candidate)

#     bleu_score /= len(ref_captions)
#     print(bleu_score)
    samples.loc[index,'caption'] = caption
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_17/3828763650.py in <module>
#       8
#       9
# ---> 10     caption = predict_caption(caption_model, record['image'], tokenizer, max_length, features)
#      11     bleu_score = 0
#      12     for ref_caption in ref_captions:
#
# /tmp/ipykernel_17/3101646607.py in predict_caption(model, image, tokenizer, max_length, features)
#       7         sequence = pad_sequences([sequence], max_length)
#       8
# ----> 9         y_pred = model.predict([feature,sequence])
#      10         y_pred = np.argmax(y_pred)
#      11
#
# /opt/conda/lib/python3.7/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1745       callbacks.on_predict_begin()
#    1746       batch_outputs = None
# -> 1747       for _, iterator in data_handler.enumerate_epochs():  # Single epoch.
#    1748         with data_handler.catch_stop_iteration():
#    1749           for step in data_handler.steps():
#
# /opt/conda/lib/python3.7/site-packages/keras/engine/data_adapter.py in enumerate_epochs(self)
#    1178     """Yields `(epoch, tf.data.Iterator)`."""
#    1179     with self._truncate_execution_to_epoch():
# -> 1180       data_iterator = iter(self._dataset)
#    1181       for epoch in range(self._initial_epoch, self._epochs):
#    1182         if self._insufficient_data:  # Set by `catch_stop_iteration`.
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/data/ops/dataset_ops.py in __iter__(self)
#     409     if context.executing_eagerly() or ops.inside_function():
#     410       with ops.colocate_with(self._variant_tensor):
# --> 411         return iterator_ops.OwnedIterator(self)
#     412     else:
#     413       raise RuntimeError("__iter__() is only supported inside of tf.function "
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/data/ops/iterator_ops.py in __init__(self, dataset, components, element_spec)
#     694       if (components is not None or element_spec is not None):
#     695         raise ValueError(error_message)
# --> 696       self._create_iterator(dataset)
#     697
#     698   def _create_iterator(self, dataset):
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/data/ops/iterator_ops.py in _create_iterator(self, dataset)
#     717               output_types=self._flat_output_types,
#     718               output_shapes=self._flat_output_shapes))
# --> 719       gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#     720       # Delete the resource when this object is deleted
#     721       self._resource_deleter = IteratorResourceDeleter(
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/ops/gen_dataset_ops.py in make_iterator(dataset, iterator, name)
#    3119     try:
#    3120       _result = pywrap_tfe.TFE_Py_FastPathExecute(
# -> 3121         _ctx, "MakeIterator", name, dataset, iterator)
#    3122       return _result
#    3123     except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
ref_captions=[]
caption_for_an_image=[]
for index,record in test.iterrows():
    if(index%5==0):
        caption_for_an_image=[]
    caption_for_an_image.append(test['caption'][index])
    if(index%5==4):
        ref_captions.append(caption_for_an_image)
print(ref_captions[0])

# %%
bleu=[]
test_captions=[]
for index,record in test.iterrows():
    
    print(index)
    test_captions.append(record['caption'].split())
    if(index%5==4):
        img = load_img(os.path.join(image_path,record['image']),target_size=(224,224))
        img = img_to_array(img)
        img = img/255.
        bleu_score = 0
        caption = predict_caption(caption_model, record['image'], tokenizer, max_length, features)
        print("Generated caption: ",caption)
        
        reference = test_captions
        candidate = caption.split()
        bleu_score = sentence_bleu(reference, candidate)
#         for ref_caption in test_captions:
#             print(ref_caption)
#             reference = ref_caption.split() # convert reference caption to list of words
#             candidate = caption.split() # convert generated caption to list of words
#             print("REFERENCE: ",reference)
#             print("CANDIDATE: ",candidate)
#             bleu_score += sentence_bleu(reference, candidate)
        print(bleu_score)
#         bleu_score /= 5
        bleu.append(bleu_score)
        print(bleu_score)
        test_captions=[]
    
    
    bleu_score = 0
#     for ref_caption in test_captions:
#         print(ref_caption)
#         reference = ref_caption[0].split() # convert reference caption to list of words
#         candidate = gen_caption.split() # convert generated caption to list of words
#         bleu_score += sentence_bleu([reference], candidate)

#     bleu_score /= len(ref_captions)
#     bleu.append(bleu_score)
#     print(bleu_score)
print(bleu)
# Out:
# 0
# 1
# 2
# 3
# 4
# Generated caption:  startseq dog is running through the grass endseq
# 0.37707945965932077
# 0.37707945965932077
# 5
# 6
# 7
# 8
# 9
# Generated caption:  startseq two dogs are playing in the water endseq
# 0.7598356856515925
# 0.7598356856515925
# 10
# 11
# 12
# 13
# 14
# Generated caption:  startseq two children are playing in the air endseq
# 0.6104735835807844
# 0.6104735835807844
# 15
# 16
# 17
# 18
# 19
# Generated caption:  startseq man is standing on the beach with the ocean endseq
# 0.8210967436686386
# 0.8210967436686386
# 20
# 21
# 22
# 23
# 24
# Generated caption:  startseq man in blue shirt is wearing red shirt and hat and hat is wearing red shirt endseq
# 0.5292031904718658
# 0.5292031904718658
# 25
# 26
# 27
# 28
# 29
# Generated caption:  startseq man in red shirt is standing on the street endseq
# 0.5022573937283119
# 0.5022573937283119
# 30
# 31
# 32
# 33
# 34
# Generated caption:  startseq man in red shirt is standing on the beach endseq
# 0.7765453555044466
# 0.7765453555044466
# 35
# 36
# 37
# 38
# 39
# Generated caption:  startseq man in red shirt is sitting on the beach endseq
# 0.33180774028439425
# 0.33180774028439425
# 40
# 41
# 42
# 43
# 44
# Generated caption:  startseq man in red shirt is standing on the beach endseq
# 0.3448444257953326
# 0.3448444257953326
# 45
# 46
# 47
# 48
# 49
# Generated caption:  startseq man in blue shirt is standing on the street in front of the water endseq
# 0.7023750892707125
# 0.7023750892707125
# 50
# 51
# 52
# 53
# 54
# Generated caption:  startseq two dogs are running through the grass endseq
# 0.6865890479690392
# 0.6865890479690392
# 55
# 56
# 57
# 58
# 59
# Generated caption:  startseq woman in blue shirt is wearing red shirt and sunglasses endseq
# 0.44116293593227063
# 0.44116293593227063
# 60
# 61
# 62
# 63
# 64
# Generated caption:  startseq two children are playing in the water endseq
# 0.5133450480401704
# 0.5133450480401704
# 65
# 66
# 67
# 68
# 69
# Generated caption:  startseq man is standing on the beach with the mountains in the background endseq
# 0.6206161803077822
# 0.6206161803077822
# 70
# 71
# 72
# 73
# 74
# Generated caption:  startseq dog is running through the grass endseq
# 0.7846630356446556
# 0.7846630356446556
# 75
# 76
# 77
# 78
# 79
# Generated caption:  startseq man in red shirt is standing on the street endseq
# 0.5972880661844315
# 0.5972880661844315
# 80
# 81
# 82
# 83
# 84
# Generated caption:  startseq man in red shirt is sitting on the beach endseq
# 0.6834466815318615
# 0.6834466815318615
# 85
# 86
# 87
# 88
# 89
# Generated caption:  startseq man in red shirt is standing on the street endseq
# 0.8432240968976374
# 0.8432240968976374
# 90
# 91
# 92
# 93
# 94
# Generated caption:  startseq man is standing on the street in front of the building endseq
# 0.7875110621102679
# 0.7875110621102679
# 95
# 96
# 97
# 98
# 99
# Generated caption:  startseq young girl in blue shirt is wearing red shirt endseq
# 0.8931539818068694
# 0.8931539818068694
# 100
# 101
# 102
# 103
# 104
# Generated caption:  startseq two children playing in the grass endseq
# 0.48109772909788073
# 0.48109772909788073
# 105
# 106
# 107
# 108
# 109
# Generated caption:  startseq man is climbing rock endseq
# 0.510029457493824
# 0.510029457493824
# 110
# 111
# 112
# 113
# 114
# Generated caption:  startseq dog is running through the water endseq
# 0.37569469583982834
# 0.37569469583982834
# 115
# 116
# 117
# 118
# 119
# Generated caption:  startseq man in red shirt is standing on the beach endseq
# 0.5491004867761125
# 0.5491004867761125
# 120
# 121
# 122
# 123
# 124
# Generated caption:  startseq man in red shirt is standing on the beach endseq
# 0.7765453555044466
# 0.7765453555044466
# 125
# 126
# 127
# 128
# 129
# Generated caption:  startseq man is standing on the beach with the camera endseq
# 0.7847084418849212
# 0.7847084418849212
# 130
# 131
# 132
# 133
# 134
# Generated caption:  startseq two children are playing in the water endseq
# 0.408248290463863
# 0.408248290463863
# 135
# 136
# 137
# 138
# 139
# Generated caption:  startseq two dogs are running through the water endseq
# 0.7598356856515925
# 0.7598356856515925
# 140
# 141
# 142
# 143
# 144
# Generated caption:  startseq man is standing on the beach endseq
# 0.8408964152537145
# 0.8408964152537145
# 145
# 146
# 147
# 148
# 149
# Generated caption:  startseq man is standing on the beach with the ocean endseq
# 0.8593887047640296
# 0.8593887047640296
# 150
# 151
# 152
# 153
# 154
# Generated caption:  startseq two dogs are playing in the grass endseq
# 0.5969491792019646
# 0.5969491792019646
# 155
# 156
# 157
# 158
# 159
# Generated caption:  startseq man is standing on the beach with the mountains endseq
# 0.8210967436686386
# 0.8210967436686386
# 160
# 161
# 162
# 163
# 164
# Generated caption:  startseq two children are playing in the water endseq
# 0.7598356856515925
# 0.7598356856515925
# 165
# 166
# 167
# 168
# 169
# Generated caption:  startseq man in blue shirt is standing on the beach endseq
# 0.4586115859713839
# 0.4586115859713839
# 170
# 171
# 172
# 173
# 174
# Generated caption:  startseq man in blue shirt is standing on the beach endseq
# 0
# Generated caption:  startseq man in red shirt is standing on the street endseq
# 0.5022573937283119
# 0.5022573937283119
# 680
# 681
# 682
# 683
# 684
# Generated caption:  startseq little girl in red shirt is sitting on the floor endseq
# 0.8408964152537145
# 0.8408964152537145
# 685
# 686
# 687
# 688
# 689
# Generated caption:  startseq man is climbing rock endseq
# 0.6025286104785453
# 0.6025286104785453
# 690
# 691
# 692
# 693
# 694
# Generated caption:  startseq man in blue shirt is standing on the street endseq
# 0.3871661495859759
# 0.3871661495859759
# 695
# 696
# 697
# 698
# 699
# Generated caption:  startseq two people are standing on the water in the water endseq
# 0.7598356856515925
# 0.7598356856515925
# 700
# 701
# 702
# 703
# 704
# Generated caption:  startseq boy in blue shirt is jumping on the street endseq
# 0.5193071778680677
# 0.5193071778680677
# 705
# 706
# 707
# 708
# 709
# Generated caption:  startseq two dogs are running through the water endseq
# 0.4518010018049224
# 0.4518010018049224
# 710
# 711
# 712
# 713
# 714
# Generated caption:  startseq man in black shirt and black and white hat is standing on the street endseq
# 0.37991784282579627
# 0.37991784282579627
# 715
# 716
# 717
# 718
# 719
# Generated caption:  startseq two dogs are running through the grass endseq
# 0.2644967217413845
# 0.2644967217413845
# 720
# 721
# 722
# 723
# 724
# Generated caption:  startseq man in blue shirt is sitting on the street endseq
# 0.6175637907926896
# 0.6175637907926896
# 725
# 726
# 727
# 728
# 729
# Generated caption:  startseq man in red shirt is standing on the beach endseq
# 0.8593887047640296
# 0.8593887047640296
# 730
# 731
# 732
# 733
# 734
# Generated caption:  startseq two dogs are playing in the water endseq
# 0.5133450480401704
# 0.5133450480401704
# 735
# 736
# 737
# 738
# 739
# Generated caption:  startseq man in blue shirt is standing on the beach endseq
# 0.7765453555044466
# 0.7765453555044466
# 740
# 741
# 742
# 743
# 744
# Generated caption:  startseq the white dog is laying on the grass endseq
# 0.4854917717073234
# 0.4854917717073234
# 745
# 746
# 747
# 748
# 749
# Generated caption:  startseq man is standing on the beach endseq
# 0.2272544758254965
# 0.2272544758254965
# 750
# 751
# 752
# 753
# 754
# Generated caption:  startseq man in red shirt is sitting on the street endseq
# 0.4366835442847812
# 0.4366835442847812
# 755
# 756
# 757
# 758
# 759
# Generated caption:  startseq girl in blue shirt is riding bike on the grass endseq
# 0.8408964152537145
# 0.8408964152537145
# 760
# 761
# 762
# 763
# 764
# Generated caption:  startseq man in red shirt is standing on the street endseq
# 0.4832697830906221
# 0.4832697830906221
# 765
# 766
# 767
# 768
# 769
# Generated caption:  startseq dog is running through the grass endseq
# 0.3096787331587729
# 0.3096787331587729
# 770
# 771
# 772
# 773
# 774
# Generated caption:  startseq dog is running through the grass endseq
# 0.7071067811865476
# 0.7071067811865476
# 775
# 776
# 777
# 778
# 779
# Generated caption:  startseq two dogs are running through the grass endseq
# 0.3303164318013807
# 0.3303164318013807
# 780
# 781
# 782
# 783
# 784
# Generated caption:  startseq dog is running through the grass endseq
# 0.355310106137518
# 0.355310106137518
# 785
# 786
# 787
# 788
# 789
# Generated caption:  startseq man is standing on the beach with the ocean endseq
# 0.8210967436686386
# 0.8210967436686386
# 790
# 791
# 792
# 793
# 794
# Generated caption:  startseq two dogs are running through the water endseq
# 0.7598356856515925
# 0.7598356856515925
# 795
# 796
# 797
# 798
# 799
# Generated caption:  startseq man in red shirt is sitting on the street endseq
# 0.46173663094410267
# 0.46173663094410267
# 800
# 801
# 802
# 803
# 804
# Generated caption:  startseq man in red shirt is sitting on the street endseq
# 0.4832697830906221
# 0.4832697830906221
# 805
# 806
# 807
# 808
# 809
# Generated caption:  startseq man in red shirt is standing on the street endseq
# 0.7497440247808671
# 0.7497440247808671
# 810
# 811
# 812
# 813
# 814
# Generated caption:  startseq man is standing on the beach endseq
# 0.42728700639623407
# 0.42728700639623407
# 815
# 816
# 817
# 818
# 819
# Generated caption:  startseq man is standing on the beach endseq
# 0.5169731539571706
# 0.5169731539571706
# 820
# 821
# 822
# 823
# 824
# Generated caption:  startseq man in red shirt is standing on the street endseq
# 0.4832697830906221
# 0.4832697830906221
# 825
# 826
# 827
# 828
# 829
# Generated caption:  startseq man in red shirt and white shirt is sitting on the street endseq
# 0.5266403878479265
# 0.5266403878479265
# 830
# 831
# 832
# 833
# 834
# Generated caption:  startseq two dogs are running through the water endseq
# 0.6640471006217092
# 0.6640471006217092
# 835
# 836
# 837
# 838
# 839
# Generated caption:  startseq man is climbing rock endseq
# 0.6025286104785453
# 0.6025286104785453
# 840
# 841
# 842
# 843
# 844
# Generated caption:  startseq man is standing on the beach endseq
# 0.3385609554882432
# 0.3385609554882432
# 845
# 846
# 847
# 848
# 849
# Generated caption:  startseq dog is running through the grass endseq
# 0.32347562464306545
# 0.32347562464306545
# 850
# 851
# 852
# 853
# 854
# Generated caption:  startseq man in blue shirt and white shirt is sitting on the camera endseq
# 0.4428500142691474
# 0.4428500142691474
# 855
# 856
# 857
# 858
# 859
# Generated caption:  startseq dog is running through the grass endseq
# 0.6803749333171202
# 0.6803749333171202
# 860
# 861
# 862
# 863
# 864
# Generated caption:  startseq man in red shirt is standing on the beach endseq
# 0.47417975608185287
# 0.47417975608185287
# 865
# 866
# 867
# 868
# 869
# Generated caption:  startseq dog is running through the grass endseq
# 0.5946035575013605
# 0.5946035575013605
# 870
# 871
# 872
# 873
# 874
# Generated caption:  startseq man in blue shirt is standing on the beach endseq
# 0.5972880661844315
# 0.5972880661844315
# 875
# 876
# 877
# 878
# 879
# Generated caption:  startseq man is standing on the beach endseq
# 0.4347208719449914
# 0.4347208719449914
# 880
# 881
# 882
# 883
# 884
# Generated caption:  startseq dog is running through the grass endseq
# 0.8408964152537145
# 0.8408964152537145
# 885
# 886
# 887
# 888
# 889
# Generated caption:  startseq two girls are playing in the grass endseq
# 0.7598356856515925
# 0.7598356856515925
# 890
# 891
# 892
# 893
# 894
# Generated caption:  startseq little girl in blue shirt is playing on the grass endseq
# 0.47987820666906633
# 0.47987820666906633
# 895
# 896
# 897
# 898
# 899
# Generated caption:  startseq man in red shirt is sitting on the street endseq
# 0.6529942057256104
# 0.6529942057256104
# 900
# 901
# 902
# 903
# 904
# Generated caption:  startseq two dogs are playing in the grass endseq
# 0.6186101569833722
# 0.6186101569833722
# 905
# 906
# 907
# 908
# 909
# Generated caption:  startseq man in red shirt is sitting on the street endseq
# 0.4832697830906221
# 0.4832697830906221
# 910
# 911
# 912
# 913
# 914
# Generated caption:  startseq dog is running through the grass endseq
# 0.3976353643835253
# 0.3976353643835253
# 915
# 916
# 917
# 918
# 919
# Generated caption:  startseq man in red shirt is standing on rock endseq
# 0.7400828044922853
# 0.7400828044922853
# 920
# 921
# 922
# 923
# 924
# Generated caption:  startseq man in red shirt is standing on the street endseq
# 0.6407117598241614
# 0.6407117598241614
# 925
# 926
# 927
# 928
# 929
# Generated caption:  startseq man is standing on the beach endseq
# 0.4153509237206396
# 0.4153509237206396
# 930
# 931
# 932
# 933
# 934
# Generated caption:  startseq man in red shirt is standing on the street endseq
# 0
149031838, 0.6175637907926896, 0.6930977286178778, 0.6500593260343691, 0.5972880661844315, 0.8091067115702212, 0.6389431042462724, 0.7598356856515925, 0.37531192687516973, 0.571751410886987, 0.5506953149031837, 0.7765453555044466, 0.4518010018049224, 0.7476743906106103, 0.31702331385234306, 0.5169731539571706, 0.5747078645171895, 0.33180774028439425, 0.8633400213704505, 0.6803749333171202, 0.537284965911771, 0.6104735835807844, 0.38890556115271097, 0.46173663094410267, 0.719408902854813, 0.6164542728425844, 0.816496580927726, 0.5133450480401704, 0.730633242658635, 0.392814650900513, 0.4216120484488188, 0.5133450480401704, 0.5247357977607321, 0.7608745412138651, 0.392814650900513, 0.48109772909788073, 0.6500593260343691, 0.8931539818068694, 0.8210967436686386, 0.33277145517762347, 0.5022573937283119, 0.8408964152537145, 0.6025286104785453, 0.3871661495859759, 0.7598356856515925, 0.5193071778680677, 0.4518010018049224, 0.37991784282579627, 0.2644967217413845, 0.6175637907926896, 0.8593887047640296, 0.5133450480401704, 0.7765453555044466, 0.4854917717073234, 0.2272544758254965, 0.4366835442847812, 0.8408964152537145, 0.4832697830906221, 0.3096787331587729, 0.7071067811865476, 0.3303164318013807, 0.355310106137518, 0.8210967436686386, 0.7598356856515925, 0.46173663094410267, 0.4832697830906221, 0.7497440247808671, 0.42728700639623407, 0.5169731539571706, 0.4832697830906221, 0.5266403878479265, 0.6640471006217092, 0.6025286104785453, 0.3385609554882432, 0.32347562464306545, 0.4428500142691474, 0.6803749333171202, 0.47417975608185287, 0.5946035575013605, 0.5972880661844315, 0.4347208719449914, 0.8408964152537145, 0.7598356856515925, 0.47987820666906633, 0.6529942057256104, 0.6186101569833722, 0.4832697830906221, 0.3976353643835253, 0.7400828044922853, 0.6407117598241614, 0.4153509237206396, 0.8593887047640296, 0.31487769219966366, 0.7730551756939454, 0.8593887047640296, 0.7289545183625967, 0.8408964152537145, 0.37531192687516973, 0.8210967436686386, 0.7598356856515925, 0.3976353643835253, 0.5022573937283119, 0.8210967436686386, 0.344844425795 ...

# %%
print('Min BLEU value: ',min(bleu))
# Out:
# Min BLEU value:  0.2202568481652174

# %%
print('Max BLEU value: ',max(bleu))
# Out:
# Max BLEU value:  0.8931539818068694

# %%
mean_bleu=sum(bleu)/len(bleu)
print('Mean BLEU value: ',round(mean_bleu,2))
# Out:
# Mean BLEU value:  0.57

# %%
import nltk.translate.bleu_score as bleu

samples = test.sample(15)
samples.reset_index(drop=True,inplace=True)

bleu_scores = []

for index,record in samples.iterrows():

    img = load_img(os.path.join(image_path,record['image']),target_size=(224,224))
    img = img_to_array(img)
    img = img/255.

    caption = predict_caption(caption_model, record['image'], tokenizer, max_length, features)
    samples.loc[index,'caption'] = caption
    
    # reference captions for the image
    references = [ref_caption.split() for ref_caption in record['caption']]
    
    # candidate caption generated by the model
    candidate = caption.split()
    
    # calculate BLEU score
    bleu_score = bleu.sentence_bleu(references, candidate)
    bleu_scores.append(bleu_score)
    
    print("BLEU score for image {}: {}".format(record['image'], bleu_score))
    
print("Average BLEU score: {}".format(sum(bleu_scores)/len(bleu_scores)))
